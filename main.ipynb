# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import geopandas
import random
import matplotlib.pyplot as plt
import math

from mip import *
import timeit

from stable_baselines3 import DQN, TD3, DDPG

# %% [markdown]
# ## Define Presets and Result File

# %%
alloc_type = 'server' # 'server':to fix number of servers and vary users, 'user': to fix number of users and vary servers
latency_threshold = 50
S = 2 #number of services


#Result file details
if alloc_type == 'user':
    U = 500 
    result_file = f'allocation_results/allocation_for_user{U}_thres{latency_threshold}.csv'

if alloc_type == 'server':
    N = 50
    result_file = f'allocation_results/allocation_for_server{N}_thres{latency_threshold}.csv'

column_names = ["user", "server", 
                "ilp_user", "ilp_time",
                "greedy_user", "greedy_time",
                "dqn_user", "dqn_time",
                "td3_user", "td3_time",
                "ddpg_user", "ddpg_time",
               ]
result_user = pd.DataFrame(columns = column_names)
result_user.to_csv(result_file, index=False)
result_user = pd.read_csv(result_file)

# %%
# Dataset and models
filename_base = 'dataset/dual_s_base.csv' #filename of data with only 1 user
model_rl = DQN.load(f"trained_agents/edge_agent_thres{latency_threshold}")
# model_exp = DQN.load("edge_agent_under_train")
model_td3 = TD3.load(f"trained_agents/td3_thres{latency_threshold}")
#model_td3 = TD3.load(f"trained_agents/td3_test")
model_ddpg = DDPG.load(f"trained_agents/ddpg_thres{latency_threshold}")
#model_ddpg = DDPG.load(f"trained_agents/ddpg_test")
users_high = 500
users_low = 100 #to calculate the users numbers from action
users_res = 100

# %%
model_ddpg

# %%
model_td3

# %% [markdown]
# ### Utility Function to Load EUA Data

# %%
#Add data to users
def add_data(series): #not used now
    random_speed = random.uniform(0,1)
    if random_speed <= 0.3:
        series['Speed']= 0
    if random_speed > 0.3 and random_speed <= 0.6:   
        series['Speed']= random.uniform(1, 2)
    if random_speed > 0.6:
        series['Speed'] = random.uniform(10, 20)
    series['Direction']= random.randrange(0, 360, 10)
    qospref = [ random.randint(1,3), random.randint(1,3) ]
    qospref.sort()
    series['LowQoS'] = qospref[0]
    series['HighQoS'] = qospref[1]
    return series

#================Load Planet Lab data
def load_planetlab():
    #Convert to triangle
    ldata = np.loadtxt('eua/PlanetLabData_1')[np.tril_indices(490)]
    ldata = ldata[ ldata != 0]
    ldata =np.unique(ldata)
    np.set_printoptions(suppress=True)
    length = ldata.shape[0]
    latency_row = 150
    latency_col = (length//latency_row) #Global Data used
    ldata = np.resize(ldata, latency_col*latency_row)
    latency = ldata.reshape(latency_row,-1)
    return latency

#=================Fetch Network latency
def fetch_network_lat(distance, latency_data):
    rep_lat = np.random.choice(latency_data[distance], size=1, replace=True)
    return rep_lat/1000 #convert latency to seconds
    

#===============User Data
def load_users(num_of_users):
    user_raw = pd.read_csv("eua/users.csv")
    user_raw = user_raw.rename_axis("UID")
    df = user_raw.sample(num_of_users)
#     user_raw = user_raw.reset_index()
    gdf = geopandas.GeoDataFrame(df, geometry = geopandas.points_from_xy(df.Longitude, df.Latitude), crs = 'epsg:4326')
    user = gdf [['geometry']] #Keep Geometry column
    user = user.to_crs(epsg=28355) #Covert the format of data
    #Insert additional data to dataframe
    #user = user.apply(add_data, axis=1)
    return user

#================Server Data
def load_servers(num_of_servers):
    server_raw = pd.read_csv("eua/servers.csv")
    server_raw = server_raw.rename_axis("SID")
    df = server_raw.sample(num_of_servers) #Sample Servers Randomly
    gdf = geopandas.GeoDataFrame(df, geometry = geopandas.points_from_xy(df.LONGITUDE, df.LATITUDE), crs = 'epsg:4326')
    server = gdf [['geometry']] #Keep Geometry column
    server = server.to_crs(epsg=28355) #Cover to crs in Australian EPSG
    def add_radius(series):
#         radius = random.randrange(150, 250, 10)
        radius = 150 #radus fixed to 150
        series.geometry = series.geometry.buffer(radius)
        #series['radius'] = radius    '''FIXED'''
#         series['resource'] = tcomp
        return series
    server = server.apply(add_radius, axis = 1)
    return server

#================neighbourhood Computing
def ngb_matrix(U, N, S): 
    #U: number of users
    #N: number of servers
    #S: number of services
    # U X N matrix
    user = load_users(U)
    server = load_servers(N)
    neighbourhood = np.zeros([U, N]) #matrix user(row) vs server(col)
    network_latency = np.zeros(N) #network latency for each server
    latency_data = load_planetlab() #load planetlad data, return matrix of bin size 150
    
    for u in range(0, U):
        for n in range(0, N):
            if server.iloc[n].geometry.contains(user.iloc[u].geometry):
                neighbourhood[u,n]=1
                #compute distance and assign latency
                distance = server.iloc[n].geometry.centroid.distance(user.iloc[u].geometry)
                rep_lat = fetch_network_lat(int(distance), latency_data) #fetch latency according to distance
                if network_latency[n] < rep_lat:
                    network_latency[n] = rep_lat
                
            else:
                neighbourhood[u,n]=0
    
    service = np.zeros(U)
    
    #assign service to the users
    for u in range(0, U):
        service[u] = random.randrange(0, S, 1) #generate a random service request to the user
        
    #find service request in each server
    server_service = np.zeros((N, S))
    
    #find the number of service request in each server
    for n in range(0, N):
        for u in range(0, U):
            if neighbourhood[u][n] == 1:
                server_service[n][int(service[u])] += 1
                
                
    
    return neighbourhood, user, server, service, server_service, network_latency

#Plot the user and server dataset on the map
def plot_data(user, server):
    # %config InlineBackend.figure_format='retina'
    # %matplotlib inline

    cbd = geopandas.read_file('eua/maps', crs = {'init': 'epsg=28355'} ) #read cbd-australia location data

    fig, ax = plt.subplots(1, 1, figsize=(15,10))
    ax.set_aspect('equal')

    ax.set_xlim(319400, 322100)
    ax.set_ylim(5811900, 5813700)

    user.plot(ax=ax, marker='o', color='red', markersize=20, zorder=3, label="users")
    server.plot(ax =ax, linestyle='dashed', edgecolor='green', linewidth=1, facecolor="none", zorder=1)
    server.centroid.plot(ax=ax, marker='s', color='blue', markersize=50, zorder=2, label="server")
    cbd.plot(ax=ax, color='grey', zorder=0, alpha = 0.3);

    ax.set_title("MEC Environment(EUA): CBD Melbourne(Australia)")
    ax.legend(bbox_to_anchor=(1, 0), loc='lower left')
    plt.show()

# %% [markdown]
# ## Load data for single user execution

# %%
def generate_server_state(num_server):
    df = pd.read_csv(filename_base)
    
#     df['ram'] = df['ram'].div(1000).round(0).astype(int)
#     df['workload_cpu'] = df['workload_cpu'].div(10).round(0).astype(int)
    df['workload_gpu'] = df['workload_gpu'].multiply(1/80).round(0).astype(int) #round gpu workload
#     df['users_yolo'] = df['users_yolo'].div(100).round(0).astype(int)
#     df['users_mnet'] = df['users_mnet'].div(100).round(0).astype(int)
    
    
    #get unique data in set
    ram = df.ram.unique()
    cores = df.cores.unique()
    workload_cpu = df.workload_cpu.unique()

    
    server_state = []
    gamma = []
    
    for s_id in range(num_server):
        #generate unique state
        gram = np.random.choice(ram, 1)[0]
        gcores = np.random.choice(cores, 1)[0]
        gwl_c = np.random.choice(workload_cpu, 1)[0]
    
        
       
        #fetch gamma for the state
        fetch_state = df.loc[ (df['ram'] == gram) & (df['cores']== gcores) & (df['workload_cpu']==gwl_c) ]
       
        gwl_g = fetch_state.sample().iloc[0]['workload_gpu'] #fetch workload randmoly
        fetch_time = fetch_state.loc[ (df['workload_gpu'] == gwl_g) ]
        
        time_yolo = fetch_time['time_yolo'].mean() #average of time for particular state
        time_mnet = fetch_time['time_mnet'].mean()
        
        gs1 = server_service[s_id][0] #assignt the state according to service request to each server
        gs2 = server_service[s_id][1] 
        server_state.append( [gram, gcores, gwl_c, gwl_g, gs1, gs2] )
        
        gamma.append((time_yolo, time_mnet)) #append the gamma value of each server
    
    return server_state, gamma

# %%
ngb, user, server, service, server_service, network_latency = ngb_matrix(50, 10, S)
server_state, gamma = generate_server_state(8)
state = server_state[5]

print(state)
action1 = model_rl.predict(np.array(state), deterministic=True)
action2 = model_td3.predict(np.array(state), deterministic=True)
action3 = model_ddpg.predict(np.array(state), deterministic=True)
print(action1[0])
print(sum(action2[0]))
print(sum(action3[0]))
# Out:
# [3000, 2, 40, 6.0, 1.0, 0.0]
# 13
# 12.000000268220901
# 9.000575244426727

# %% [markdown]
# # Algorithms

# %% [markdown]
# ### ILP Algorithm

# %%
def ilp_algo():
    ## ===================================ILP with python mip
    # >> solver_name=GRB
    # >> Currently using CBC
    I = range(U) #user
    J = range(N) #server

    alloc = Model(sense=MAXIMIZE, name="alloc", solver_name=CBC)

    def coverage(user_ix, server_ix):
        if ngb[user_ix][server_ix]==1:
            return 1
        else:
            return 0

    #U: num of users, N: num of servers
    x = [[ alloc.add_var(f"x{i}{j}", var_type=BINARY) for j in J] for i in I]

    #Objective Equation
    alloc.objective = xsum( x[i][j]  for i in I for j in J )

    #1 .Coverage Constraint
    for i in I:
        for j in J:        
                if not coverage(i,j):
                    alloc += x[i][j] == 0

    #2. User allocation to single server constrain
    for i in I:
        alloc += xsum( x[i][j] for j in J ) <=1

    #3. Latency Constraint
    for j in J:
        alloc += xsum( gamma[j][int(service[i])]*x[i][j] for i in I ) <=latency_threshold-network_latency[j] 

    #alloc.write("test-model.lp")

    #===========Start Optimization=========
    alloc.optimize(max_seconds=25)

    #==========ILP Ends here
    #print(f"Number of Solutions:{qoe.num_solutions}")
    ilp_allocation = [ (i,j) for i in I for j in J if x[i][j].x >= 0.99]

    #print(f"Number of Solutions:{qoe.num_solutions}")
    #print(f"Objective Value:{qoe.objective_value}")
    allocated_num_users = len(ilp_allocation)
    print("ILP Allocated Num of Users: {}".format(allocated_num_users))
    # selected.sort()
    return ilp_allocation

# %% [markdown]
# ### RL Allocation Algorithm

# %%
#Load model
def rl_algo():
    #for each server find the number of possible users using model
    server_capacity = np.zeros((N, S))
    for server_id in range(N):
        state = server_state[server_id]
#         if model_type == 'lin':
        action = model_rl.predict(np.array(state), deterministic=True)
#        print(action)
#         if model_type == 'exp':
#             action = model_exp.predict(np.array(state), deterministic=True)
        u1 = action[0]//5 + 1
        u2 = (action[0]+1) - (u1-1)*5
        server_capacity[server_id][0] = u1*100 #model output
        server_capacity[server_id][1] = u2*100 #model output
        
    #sort with number of servers per user
    col1 = np.array([np.sum(ngb,axis=1)])
    col2 = np.array([np.arange(U)])
    sorted_ngb = np.concatenate((ngb, col1.T, col2.T), axis=1) #add rowsum and index column
    sorted_ngb = sorted_ngb[np.argsort(sorted_ngb[:, N])] #sort the rows based on rowsum column

    #allocation heuristic
    #run allocation algorithm
    rl_allocation = []

    for i in range(U):
        server_list = np.where(sorted_ngb[i, :N] == 1)[0] #get the list of server to which user is connected

        if len(server_list) == 0: #skip users with no server
            continue
        
        ser = int(service[i]) #which service user is requesting
        choosen_server = server_list[np.argmax(server_capacity[server_list, ser])] #find the id of choosen server
        
        
        if  server_capacity[choosen_server][ser] > 0: #assigning user to choosen_server
            server_capacity[choosen_server][ser] -= 1 #decrement the server capacity

            rl_allocation.append( (int(sorted_ngb[i, N+1]), choosen_server) ) #(user, server) alloc pair
    print('RL Num of allocation: {}'.format(len(rl_allocation)))
#    print(rl_allocation)
    return rl_allocation

# %%
#Load model
def td3_algo():
    #for each server find the number of possible users using model
    server_capacity = np.zeros((N, S))
    for server_id in range(N):
        state = server_state[server_id]
#         if model_type == 'lin':
        action = sum(model_td3.predict(np.array(state), deterministic=True)[0])
#        print(action)
#         if model_type == 'exp':
#             action = model_exp.predict(np.array(state), deterministic=True)
        u1 = action//5 + 1
        u2 = (action+1) - (u1-1)*5
        server_capacity[server_id][0] = u1*100 #model output
        server_capacity[server_id][1] = u2*100 #model output
        
    #sort with number of servers per user
    col1 = np.array([np.sum(ngb,axis=1)])
    col2 = np.array([np.arange(U)])
    sorted_ngb = np.concatenate((ngb, col1.T, col2.T), axis=1) #add rowsum and index column
    sorted_ngb = sorted_ngb[np.argsort(sorted_ngb[:, N])] #sort the rows based on rowsum column

    #allocation heuristic
    #run allocation algorithm
    rl_allocation = []

    for i in range(U):
        server_list = np.where(sorted_ngb[i, :N] == 1)[0] #get the list of server to which user is connected

        if len(server_list) == 0: #skip users with no server
            continue
        
        ser = int(service[i]) #which service user is requesting
        choosen_server = server_list[np.argmax(server_capacity[server_list, ser])] #find the id of choosen server
        
        
        if  server_capacity[choosen_server][ser] > 0: #assigning user to choosen_server
            server_capacity[choosen_server][ser] -= 1 #decrement the server capacity

            rl_allocation.append( (int(sorted_ngb[i, N+1]), choosen_server) ) #(user, server) alloc pair
    print('TD3 Num of allocation: {}'.format(len(rl_allocation)))
#    print(rl_allocation)
    return rl_allocation

# %%
#Load model
def ddpg_algo():
    #for each server find the number of possible users using model
    server_capacity = np.zeros((N, S))
    for server_id in range(N):
        state = server_state[server_id]
#         if model_type == 'lin':
        action = sum(model_ddpg.predict(np.array(state), deterministic=True)[0])
#        print(action)
#         if model_type == 'exp':
#             action = model_exp.predict(np.array(state), deterministic=True)
        u1 = action//5 + 1
        u2 = (action+1) - (u1-1)*5
        server_capacity[server_id][0] = u1*100 #model output
        server_capacity[server_id][1] = u2*100 #model output
        
    #sort with number of servers per user
    col1 = np.array([np.sum(ngb,axis=1)])
    col2 = np.array([np.arange(U)])
    sorted_ngb = np.concatenate((ngb, col1.T, col2.T), axis=1) #add rowsum and index column
    sorted_ngb = sorted_ngb[np.argsort(sorted_ngb[:, N])] #sort the rows based on rowsum column

    #allocation heuristic
    #run allocation algorithm
    rl_allocation = []

    for i in range(U):
        server_list = np.where(sorted_ngb[i, :N] == 1)[0] #get the list of server to which user is connected

        if len(server_list) == 0: #skip users with no server
            continue
        
        ser = int(service[i]) #which service user is requesting
        choosen_server = server_list[np.argmax(server_capacity[server_list, ser])] #find the id of choosen server
        
        
        if  server_capacity[choosen_server][ser] > 0: #assigning user to choosen_server
            server_capacity[choosen_server][ser] -= 1 #decrement the server capacity

            rl_allocation.append( (int(sorted_ngb[i, N+1]), choosen_server) ) #(user, server) alloc pair
    print('DDPG Num of allocation: {}'.format(len(rl_allocation)))
    return rl_allocation

# %% [markdown]
# ### Nearest Neighbourhood Greedy Algorithm

# %%
def greedy_algo():
    server_capacity = np.zeros(N)
    rl_allocation = []
    for user_id in range(U):
        server_ngb_list = np.where(ngb[user_id, :N] == 1)[0] #get the list of server to which user is connected
        if len(server_ngb_list) == 0: #ignore the users which are not under any servers
            continue 
    
        #find the distance to each users in the server_ngb_list
        dist_list = np.array([ server_ngb_list, [server.iloc[i]['geometry'].centroid.distance(user.iloc[user_id]['geometry']) for i in server_ngb_list] ])
        # sorted list of servers based on the distance from users
        sorted_distance_list = dist_list[ :, dist_list[1].argsort()]
        #get the list of servers arranged in least to max distance
        server_list = sorted_distance_list[0].astype(int)
        
        lat = 0
        for server_id in server_list:
            lat = gamma[server_id][int(service[user_id])]
            if server_capacity[server_id]+lat <= latency_threshold-network_latency[server_id]:
                server_capacity[server_id] += lat #increment the server_capacity of server
                rl_allocation.append( (user_id, server_id) ) #(user, server) alloc pair
                break
    
    print('Greedy-Ngb Num of allocation: {}'.format(len(rl_allocation)))
    return rl_allocation

# %% [markdown]
# # main(): Iterative Loop to generate results for various user server configuration

# %%
if alloc_type == 'user': #user fix, vary number of servers
    for N in range(20, 100, 20):
    #     for N in range(20, 100, 20):
        for epoch in range(50):
            print("User:", U, 'Server:', N, 'Epoch:', epoch)
    #             U = 50 #Number of users #Define U, N and ngb Matrix
    #             N = 10 #Number of Servers
            ngb, user, server, service, server_service, network_latency = ngb_matrix(U, N, S) #generate server and user from EUA data #determine neighbourhood matrix
            server_state, gamma = generate_server_state(N) #assign state and gamma for each user

            #=======ILP starts
            start = 0
            stop = 0
            execution_time_ilp = 0
            start = timeit.default_timer()

            ilp_aloc = ilp_algo() #call ILP algorithm

            stop = timeit.default_timer()
            execution_time_ilp = stop - start
            #========ILP ends

            #=======Greedy starts
            start = 0
            stop = 0
            execution_time_greedy = 0
            start = timeit.default_timer()

            greedy_aloc = greedy_algo() #call ILP algorithm

            stop = timeit.default_timer()
            execution_time_greedy = stop - start
            #========Greedy ends

            #=======RL starts
            start = 0
            stop = 0
            execution_time_rl = 0
            start = timeit.default_timer()

            rl_aloc = rl_algo() #call ILP algorithm

            stop = timeit.default_timer()
            execution_time_rl = stop - start
            #========RL_linear ends

            #=======td3 starts
            start = 0
            stop = 0
            execution_time_td3 = 0
            start = timeit.default_timer()

            td3_aloc = td3_algo() #call ILP algorithm

            stop = timeit.default_timer()
            execution_time_td3 = stop - start
            #=======td3_linear ends
            
            #=======ddpg starts
            start = 0
            stop = 0
            execution_time_ddpg = 0
            start = timeit.default_timer()

            ddpg_aloc = ddpg_algo() #call ILP algorithm

            stop = timeit.default_timer()
            execution_time_ddpg = stop - start
            #========ddpg_linear ends

            #========Store results to file
            to_append = [U, N,
                         len(ilp_aloc), execution_time_ilp,
                         len(greedy_aloc), execution_time_greedy,
                         len(rl_aloc), execution_time_rl,
                         len(td3_aloc), execution_time_td3,
                         len(ddpg_aloc), execution_time_ddpg,
                        ] 
            dseries = pd.Series(to_append, index = result_user.columns)
            result_user = result_user.append(dseries, ignore_index=True)
            print("epoch:", epoch)
    result_user.to_csv(result_file, index=False)

# %%
#result_user

# %%
if alloc_type == 'server': #server fix, vary number of users
    for U in range(100, 600, 100):
        for epoch in range(50):
            print("\n---------------------------------------")
            print("User:", U, 'Server:', N, 'Epoch:', epoch)
    #             U = 50 #Number of users #Define U, N and ngb Matrix
    #             N = 10 #Number of Servers
            ngb, user, server, service, server_service, network_latency = ngb_matrix(U, N, S) #generate server and user from EUA data #determine neighbourhood matrix
            server_state, gamma = generate_server_state(N) #assign state and gamma for each user

            #=======ILP starts
            start = 0
            stop = 0
            execution_time_ilp = 0
            start = timeit.default_timer()

            ilp_aloc = ilp_algo() #call ILP algorithm

            stop = timeit.default_timer()
            execution_time_ilp = stop - start
            #========ILP ends

            #=======Greedy starts
            start = 0
            stop = 0
            execution_time_greedy = 0
            start = timeit.default_timer()

            greedy_aloc = greedy_algo() #call ILP algorithm

            stop = timeit.default_timer()
            execution_time_greedy = stop - start
            #========Greedy ends

            #=======RL_linear starts
            start = 0
            stop = 0
            execution_time_rl = 0
            start = timeit.default_timer()

            rl_aloc = rl_algo() #call ILP algorithm

            stop = timeit.default_timer()
            execution_time_rl = stop - start
            #========RL_linear ends


           #=======td3 starts
            start = 0
            stop = 0
            execution_time_td3 = 0
            start = timeit.default_timer()

            td3_aloc = td3_algo() #call ILP algorithm

            stop = timeit.default_timer()
            execution_time_td3 = stop - start
            #=======td3_linear ends
            
            #=======ddpg starts
            start = 0
            stop = 0
            execution_time_ddpg = 0
            start = timeit.default_timer()

            ddpg_aloc = ddpg_algo() #call ILP algorithm

            stop = timeit.default_timer()
            execution_time_ddpg = stop - start
            #========ddpg_linear ends

            #========Store results to file
            to_append = [U, N,
                         len(ilp_aloc), execution_time_ilp,
                         len(greedy_aloc), execution_time_greedy,
                         len(rl_aloc), execution_time_rl,
                         len(td3_aloc), execution_time_td3,
                         len(ddpg_aloc), execution_time_ddpg,
                        ] 
            dseries = pd.Series(to_append, index = result_user.columns)
            result_user = result_user.append(dseries, ignore_index=True)
            print("epoch:", epoch)
    result_user.to_csv(result_file, index=False)
# Out:
# ---------------------------------------
# User: 100 Server: 50 Epoch: 0
# ILP Allocated Num of Users: 79
# Greedy-Ngb Num of allocation: 79
# RL Num of allocation: 79
# TD3 Num of allocation: 79
# DDPG Num of allocation: 79
# epoch: 0
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 1
# ILP Allocated Num of Users: 80
# Greedy-Ngb Num of allocation: 80
# RL Num of allocation: 80
# TD3 Num of allocation: 80
# DDPG Num of allocation: 80
# epoch: 1
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 2
# ILP Allocated Num of Users: 88
# Greedy-Ngb Num of allocation: 88
# RL Num of allocation: 88
# TD3 Num of allocation: 88
# DDPG Num of allocation: 88
# epoch: 2
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 3
# ILP Allocated Num of Users: 83
# Greedy-Ngb Num of allocation: 83
# RL Num of allocation: 83
# TD3 Num of allocation: 83
# DDPG Num of allocation: 83
# epoch: 3
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 4
# ILP Allocated Num of Users: 83
# Greedy-Ngb Num of allocation: 83
# RL Num of allocation: 83
# TD3 Num of allocation: 83
# DDPG Num of allocation: 83
# epoch: 4
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 5
# ILP Allocated Num of Users: 77
# Greedy-Ngb Num of allocation: 77
# RL Num of allocation: 77
# TD3 Num of allocation: 77
# DDPG Num of allocation: 77
# epoch: 5
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 6
# ILP Allocated Num of Users: 91
# Greedy-Ngb Num of allocation: 91
# RL Num of allocation: 91
# TD3 Num of allocation: 91
# DDPG Num of allocation: 91
# epoch: 6
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 7
# ILP Allocated Num of Users: 76
# Greedy-Ngb Num of allocation: 76
# RL Num of allocation: 76
# TD3 Num of allocation: 76
# DDPG Num of allocation: 76
# epoch: 7
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 8
# ILP Allocated Num of Users: 87
# Greedy-Ngb Num of allocation: 87
# RL Num of allocation: 87
# TD3 Num of allocation: 87
# DDPG Num of allocation: 87
# epoch: 8
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 9
# ILP Allocated Num of Users: 79
# Greedy-Ngb Num of allocation: 79
# RL Num of allocation: 79
# TD3 Num of allocation: 79
# DDPG Num of allocation: 79
# epoch: 9
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 10
# ILP Allocated Num of Users: 86
# Greedy-Ngb Num of allocation: 86
# RL Num of allocation: 86
# TD3 Num of allocation: 86
# DDPG Num of allocation: 86
# epoch: 10
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 11
# ILP Allocated Num of Users: 86
# Greedy-Ngb Num of allocation: 86
# RL Num of allocation: 86
# TD3 Num of allocation: 86
# DDPG Num of allocation: 86
# epoch: 11
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 12
# ILP Allocated Num of Users: 80
# Greedy-Ngb Num of allocation: 80
# RL Num of allocation: 80
# TD3 Num of allocation: 80
# DDPG Num of allocation: 80
# epoch: 12
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 13
# ILP Allocated Num of Users: 84
# Greedy-Ngb Num of allocation: 84
# RL Num of allocation: 84
# TD3 Num of allocation: 84
# DDPG Num of allocation: 84
# epoch: 13
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 14
# ILP Allocated Num of Users: 81
# Greedy-Ngb Num of allocation: 81
# RL Num of allocation: 81
# TD3 Num of allocation: 81
# DDPG Num of allocation: 81
# epoch: 14
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 15
# ILP Allocated Num of Users: 81
# Greedy-Ngb Num of allocation: 81
# RL Num of allocation: 81
# TD3 Num of allocation: 81
# DDPG Num of allocation: 81
# epoch: 15
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 16
# ILP Allocated Num of Users: 78
# Greedy-Ngb Num of allocation: 78
# RL Num of allocation: 78
# TD3 Num of allocation: 78
# DDPG Num of allocation: 78
# epoch: 16
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 17
# ILP Allocated Num of Users: 84
# Greedy-Ngb Num of allocation: 84
# RL Num of allocation: 84
# TD3 Num of allocation: 84
# DDPG Num of allocation: 84
# epoch: 17
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 18
# ILP Allocated Num of Users: 81
# Greedy-Ngb Num of allocation: 81
# RL Num of allocation: 81
# TD3 Num of allocation: 81
# DDPG Num of allocation: 81
# epoch: 18
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 19
# ILP Allocated Num of Users: 84
# Greedy-Ngb Num of allocation: 84
# RL Num of allocation: 84
# TD3 Num of allocation: 84
# DDPG Num of allocation: 84
# epoch: 19
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 20
# ILP Allocated Num of Users: 80
# Greedy-Ngb Num of allocation: 80
# RL Num of allocation: 80
# TD3 Num of allocation: 80
# DDPG Num of allocation: 80
# epoch: 20
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 21
# ILP Allocated Num of Users: 85
# Greedy-Ngb Num of allocation: 85
# RL Num of allocation: 85
# TD3 Num of allocation: 85
# DDPG Num of allocation: 85
# epoch: 21
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 22
# ILP Allocated Num of Users: 85
# Greedy-Ngb Num of allocation: 85
# RL Num of allocation: 85
# TD3 Num of allocation: 85
# DDPG Num of allocation: 85
# epoch: 22
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 23
# ILP Allocated Num of Users: 85
# Greedy-Ngb Num of allocation: 85
# RL Num of allocation: 85
# TD3 Num of allocation: 85
# DDPG Num of allocation: 85
# epoch: 23
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 24
# ILP Allocated Num of Users: 77
# Greedy-Ngb Num of allocation: 77
# RL Num of allocation: 77
# TD3 Num of allocation: 77
# DDPG Num of allocation: 77
# epoch: 24
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 25
# ILP Allocated Num of Users: 92
# Greedy-Ngb Num of allocation: 92
# RL Num of allocation: 92
# TD3 Num of allocation: 92
# DDPG Num of allocation: 92
# epoch: 25
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 26
# ILP Allocated Num of Users: 79
# Greedy-Ngb Num of allocation: 79
# RL Num of allocation: 79
# TD3 Num of allocation: 79
# DDPG Num of allocation: 79
# epoch: 26
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 27
# ILP Allocated Num of Users: 84
# Greedy-Ngb Num of allocation: 84
# RL Num of allocation: 84
# TD3 Num of allocation: 84
# DDPG Num of allocation: 84
# epoch: 27
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 28
# ILP Allocated Num of Users: 76
# Greedy-Ngb Num of allocation: 76
# RL Num of allocation: 76
# TD3 Num of allocation: 76
# DDPG Num of allocation: 76
# epoch: 28
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 29
# ILP Allocated Num of Users: 83
# Greedy-Ngb Num of allocation: 83
# RL Num of allocation: 84
# TD3 Num of allocation: 84
# DDPG Num of allocation: 84
# epoch: 29
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 30
# ILP Allocated Num of Users: 79
# Greedy-Ngb Num of allocation: 79
# RL Num of allocation: 79
# TD3 Num of allocation: 79
# DDPG Num of allocation: 79
# epoch: 30
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 31
# ILP Allocated Num of Users: 81
# Greedy-Ngb Num of allocation: 81
# RL Num of allocation: 81
# TD3 Num of allocation: 81
# DDPG Num of allocation: 81
# epoch: 31
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 32
# ILP Allocated Num of Users: 90
# Greedy-Ngb Num of allocation: 90
# RL Num of allocation: 90
# TD3 Num of allocation: 90
# DDPG Num of allocation: 90
# epoch: 32
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 33
# ILP Allocated Num of Users: 83
# Greedy-Ngb Num of allocation: 83
# RL Num of allocation: 83
# TD3 Num of allocation: 83
# DDPG Num of allocation: 83
# epoch: 33
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 34
# ILP Allocated Num of Users: 85
# Greedy-Ngb Num of allocation: 85
# RL Num of allocation: 85
# TD3 Num of allocation: 85
# DDPG Num of allocation: 85
# epoch: 34
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 35
# ILP Allocated Num of Users: 80
# Greedy-Ngb Num of allocation: 80
# RL Num of allocation: 80
# TD3 Num of allocation: 80
# DDPG Num of allocation: 80
# epoch: 35
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 36
# ILP Allocated Num of Users: 83
# Greedy-Ngb Num of allocation: 83
# RL Num of allocation: 83
# TD3 Num of allocation: 83
# DDPG Num of allocation: 83
# epoch: 36
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 37
# ILP Allocated Num of Users: 82
# Greedy-Ngb Num of allocation: 82
# RL Num of allocation: 82
# TD3 Num of allocation: 82
# DDPG Num of allocation: 82
# epoch: 37
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 38
# ILP Allocated Num of Users: 81
# Greedy-Ngb Num of allocation: 81
# RL Num of allocation: 81
# TD3 Num of allocation: 81
# DDPG Num of allocation: 81
# epoch: 38
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 39
# ILP Allocated Num of Users: 85
# Greedy-Ngb Num of allocation: 85
# RL Num of allocation: 85
# TD3 Num of allocation: 85
# DDPG Num of allocation: 85
# epoch: 39
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 40
# ILP Allocated Num of Users: 87
# Greedy-Ngb Num of allocation: 87
# RL Num of allocation: 87
# TD3 Num of allocation: 87
# DDPG Num of allocation: 87
# epoch: 40
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 41
# ILP Allocated Num of Users: 73
# Greedy-Ngb Num of allocation: 73
# RL Num of allocation: 73
# TD3 Num of allocation: 73
# DDPG Num of allocation: 73
# epoch: 41
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 42
# ILP Allocated Num of Users: 76
# Greedy-Ngb Num of allocation: 76
# RL Num of allocation: 76
# TD3 Num of allocation: 76
# DDPG Num of allocation: 76
# epoch: 42
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 43
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 71
# RL Num of allocation: 71
# TD3 Num of allocation: 71
# DDPG Num of allocation: 71
# epoch: 43
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 44
# ILP Allocated Num of Users: 79
# Greedy-Ngb Num of allocation: 79
# RL Num of allocation: 79
# TD3 Num of allocation: 79
# DDPG Num of allocation: 79
# epoch: 44
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 45
# ILP Allocated Num of Users: 87
# Greedy-Ngb Num of allocation: 87
# RL Num of allocation: 87
# TD3 Num of allocation: 87
# DDPG Num of allocation: 87
# epoch: 45
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 46
# ILP Allocated Num of Users: 76
# Greedy-Ngb Num of allocation: 76
# RL Num of allocation: 76
# TD3 Num of allocation: 76
# DDPG Num of allocation: 76
# epoch: 46
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 47
# ILP Allocated Num of Users: 82
# Greedy-Ngb Num of allocation: 82
# RL Num of allocation: 82
# TD3 Num of allocation: 82
# DDPG Num of allocation: 82
# epoch: 47
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 48
# ILP Allocated Num of Users: 83
# Greedy-Ngb Num of allocation: 83
# RL Num of allocation: 83
# TD3 Num of allocation: 83
# DDPG Num of allocation: 83
# epoch: 48
#
# ---------------------------------------
# User: 100 Server: 50 Epoch: 49
# ILP Allocated Num of Users: 81
# Greedy-Ngb Num of allocation: 81
# RL Num of allocation: 81
# TD3 Num of allocation: 81
# DDPG Num of allocation: 81
# epoch: 49
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 0
# ILP Allocated Num of Users: 163
# Greedy-Ngb Num of allocation: 162
# RL Num of allocation: 169
# TD3 Num of allocation: 169
# DDPG Num of allocation: 169
# epoch: 0
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 1
# ILP Allocated Num of Users: 162
# Greedy-Ngb Num of allocation: 162
# RL Num of allocation: 162
# TD3 Num of allocation: 162
# DDPG Num of allocation: 162
# epoch: 1
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 2
# ILP Allocated Num of Users: 166
# Greedy-Ngb Num of allocation: 166
# RL Num of allocation: 166
# TD3 Num of allocation: 166
# DDPG Num of allocation: 166
# epoch: 2
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 3
# ILP Allocated Num of Users: 162
# Greedy-Ngb Num of allocation: 162
# RL Num of allocation: 162
# TD3 Num of allocation: 162
# DDPG Num of allocation: 162
# epoch: 3
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 4
# ILP Allocated Num of Users: 159
# Greedy-Ngb Num of allocation: 158
# RL Num of allocation: 160
# TD3 Num of allocation: 160
# DDPG Num of allocation: 160
# epoch: 4
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 5
# ILP Allocated Num of Users: 152
# Greedy-Ngb Num of allocation: 150
# RL Num of allocation: 152
# TD3 Num of allocation: 152
# DDPG Num of allocation: 152
# epoch: 5
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 6
# ILP Allocated Num of Users: 173
# Greedy-Ngb Num of allocation: 171
# RL Num of allocation: 175
# TD3 Num of allocation: 175
# DDPG Num of allocation: 175
# epoch: 6
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 7
# ILP Allocated Num of Users: 175
# Greedy-Ngb Num of allocation: 175
# RL Num of allocation: 175
# TD3 Num of allocation: 175
# DDPG Num of allocation: 175
# epoch: 7
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 8
# ILP Allocated Num of Users: 166
# Greedy-Ngb Num of allocation: 166
# RL Num of allocation: 166
# TD3 Num of allocation: 166
# DDPG Num of allocation: 166
# epoch: 8
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 9
# ILP Allocated Num of Users: 171
# Greedy-Ngb Num of allocation: 171
# RL Num of allocation: 172
# TD3 Num of allocation: 172
# DDPG Num of allocation: 172
# epoch: 9
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 10
# ILP Allocated Num of Users: 146
# Greedy-Ngb Num of allocation: 146
# RL Num of allocation: 146
# TD3 Num of allocation: 146
# DDPG Num of allocation: 146
# epoch: 10
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 11
# ILP Allocated Num of Users: 162
# Greedy-Ngb Num of allocation: 161
# RL Num of allocation: 164
# TD3 Num of allocation: 164
# DDPG Num of allocation: 164
# epoch: 11
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 12
# ILP Allocated Num of Users: 161
# Greedy-Ngb Num of allocation: 158
# RL Num of allocation: 163
# TD3 Num of allocation: 163
# DDPG Num of allocation: 163
# epoch: 12
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 13
# ILP Allocated Num of Users: 166
# Greedy-Ngb Num of allocation: 165
# RL Num of allocation: 166
# TD3 Num of allocation: 166
# DDPG Num of allocation: 166
# epoch: 13
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 14
# ILP Allocated Num of Users: 164
# Greedy-Ngb Num of allocation: 163
# RL Num of allocation: 164
# TD3 Num of allocation: 164
# DDPG Num of allocation: 164
# epoch: 14
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 15
# ILP Allocated Num of Users: 158
# Greedy-Ngb Num of allocation: 158
# RL Num of allocation: 158
# TD3 Num of allocation: 158
# DDPG Num of allocation: 158
# epoch: 15
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 16
# ILP Allocated Num of Users: 159
# Greedy-Ngb Num of allocation: 158
# RL Num of allocation: 162
# TD3 Num of allocation: 162
# DDPG Num of allocation: 162
# epoch: 16
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 17
# ILP Allocated Num of Users: 183
# Greedy-Ngb Num of allocation: 182
# RL Num of allocation: 183
# TD3 Num of allocation: 183
# DDPG Num of allocation: 183
# epoch: 17
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 18
# ILP Allocated Num of Users: 168
# Greedy-Ngb Num of allocation: 167
# RL Num of allocation: 168
# TD3 Num of allocation: 168
# DDPG Num of allocation: 168
# epoch: 18
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 19
# ILP Allocated Num of Users: 147
# Greedy-Ngb Num of allocation: 147
# RL Num of allocation: 147
# TD3 Num of allocation: 147
# DDPG Num of allocation: 147
# epoch: 19
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 20
# ILP Allocated Num of Users: 142
# Greedy-Ngb Num of allocation: 142
# RL Num of allocation: 142
# TD3 Num of allocation: 142
# DDPG Num of allocation: 142
# epoch: 20
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 21
# ILP Allocated Num of Users: 147
# Greedy-Ngb Num of allocation: 147
# RL Num of allocation: 147
# TD3 Num of allocation: 147
# DDPG Num of allocation: 147
# epoch: 21
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 22
# ILP Allocated Num of Users: 151
# Greedy-Ngb Num of allocation: 151
# RL Num of allocation: 151
# TD3 Num of allocation: 151
# DDPG Num of allocation: 151
# epoch: 22
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 23
# ILP Allocated Num of Users: 165
# Greedy-Ngb Num of allocation: 165
# RL Num of allocation: 165
# TD3 Num of allocation: 165
# DDPG Num of allocation: 165
# epoch: 23
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 24
# ILP Allocated Num of Users: 173
# Greedy-Ngb Num of allocation: 170
# RL Num of allocation: 173
# TD3 Num of allocation: 173
# DDPG Num of allocation: 173
# epoch: 24
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 25
# ILP Allocated Num of Users: 172
# Greedy-Ngb Num of allocation: 171
# RL Num of allocation: 172
# TD3 Num of allocation: 172
# DDPG Num of allocation: 172
# epoch: 25
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 26
# ILP Allocated Num of Users: 171
# Greedy-Ngb Num of allocation: 171
# RL Num of allocation: 171
# TD3 Num of allocation: 171
# DDPG Num of allocation: 171
# epoch: 26
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 27
# ILP Allocated Num of Users: 168
# Greedy-Ngb Num of allocation: 168
# RL Num of allocation: 168
# TD3 Num of allocation: 168
# DDPG Num of allocation: 168
# epoch: 27
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 28
# ILP Allocated Num of Users: 152
# Greedy-Ngb Num of allocation: 152
# RL Num of allocation: 152
# TD3 Num of allocation: 152
# DDPG Num of allocation: 152
# epoch: 28
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 29
# ILP Allocated Num of Users: 153
# Greedy-Ngb Num of allocation: 153
# RL Num of allocation: 153
# TD3 Num of allocation: 153
# DDPG Num of allocation: 153
# epoch: 29
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 30
# ILP Allocated Num of Users: 170
# Greedy-Ngb Num of allocation: 169
# RL Num of allocation: 170
# TD3 Num of allocation: 170
# DDPG Num of allocation: 170
# epoch: 30
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 31
# ILP Allocated Num of Users: 161
# Greedy-Ngb Num of allocation: 160
# RL Num of allocation: 161
# TD3 Num of allocation: 161
# DDPG Num of allocation: 161
# epoch: 31
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 32
# ILP Allocated Num of Users: 170
# Greedy-Ngb Num of allocation: 170
# RL Num of allocation: 170
# TD3 Num of allocation: 170
# DDPG Num of allocation: 170
# epoch: 32
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 33
# ILP Allocated Num of Users: 165
# Greedy-Ngb Num of allocation: 165
# RL Num of allocation: 165
# TD3 Num of allocation: 165
# DDPG Num of allocation: 165
# epoch: 33
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 34
# ILP Allocated Num of Users: 172
# Greedy-Ngb Num of allocation: 172
# RL Num of allocation: 172
# TD3 Num of allocation: 172
# DDPG Num of allocation: 172
# epoch: 34
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 35
# ILP Allocated Num of Users: 173
# Greedy-Ngb Num of allocation: 173
# RL Num of allocation: 173
# TD3 Num of allocation: 173
# DDPG Num of allocation: 173
# epoch: 35
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 36
# ILP Allocated Num of Users: 162
# Greedy-Ngb Num of allocation: 162
# RL Num of allocation: 162
# TD3 Num of allocation: 162
# DDPG Num of allocation: 162
# epoch: 36
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 37
# ILP Allocated Num of Users: 163
# Greedy-Ngb Num of allocation: 163
# RL Num of allocation: 164
# TD3 Num of allocation: 164
# DDPG Num of allocation: 164
# epoch: 37
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 38
# ILP Allocated Num of Users: 167
# Greedy-Ngb Num of allocation: 167
# RL Num of allocation: 167
# TD3 Num of allocation: 167
# DDPG Num of allocation: 167
# epoch: 38
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 39
# ILP Allocated Num of Users: 160
# Greedy-Ngb Num of allocation: 160
# RL Num of allocation: 160
# TD3 Num of allocation: 160
# DDPG Num of allocation: 160
# epoch: 39
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 40
# ILP Allocated Num of Users: 156
# Greedy-Ngb Num of allocation: 156
# RL Num of allocation: 156
# TD3 Num of allocation: 156
# DDPG Num of allocation: 156
# epoch: 40
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 41
# ILP Allocated Num of Users: 162
# Greedy-Ngb Num of allocation: 162
# RL Num of allocation: 164
# TD3 Num of allocation: 164
# DDPG Num of allocation: 164
# epoch: 41
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 42
# ILP Allocated Num of Users: 153
# Greedy-Ngb Num of allocation: 153
# RL Num of allocation: 153
# TD3 Num of allocation: 153
# DDPG Num of allocation: 153
# epoch: 42
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 43
# ILP Allocated Num of Users: 162
# Greedy-Ngb Num of allocation: 158
# RL Num of allocation: 162
# TD3 Num of allocation: 162
# DDPG Num of allocation: 162
# epoch: 43
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 44
# ILP Allocated Num of Users: 154
# Greedy-Ngb Num of allocation: 153
# RL Num of allocation: 154
# TD3 Num of allocation: 154
# DDPG Num of allocation: 154
# epoch: 44
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 45
# ILP Allocated Num of Users: 155
# Greedy-Ngb Num of allocation: 155
# RL Num of allocation: 157
# TD3 Num of allocation: 157
# DDPG Num of allocation: 157
# epoch: 45
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 46
# ILP Allocated Num of Users: 160
# Greedy-Ngb Num of allocation: 155
# RL Num of allocation: 160
# TD3 Num of allocation: 160
# DDPG Num of allocation: 160
# epoch: 46
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 47
# ILP Allocated Num of Users: 165
# Greedy-Ngb Num of allocation: 165
# RL Num of allocation: 165
# TD3 Num of allocation: 165
# DDPG Num of allocation: 165
# epoch: 47
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 48
# ILP Allocated Num of Users: 166
# Greedy-Ngb Num of allocation: 165
# RL Num of allocation: 166
# TD3 Num of allocation: 166
# DDPG Num of allocation: 166
# epoch: 48
#
# ---------------------------------------
# User: 200 Server: 50 Epoch: 49
# ILP Allocated Num of Users: 165
# Greedy-Ngb Num of allocation: 163
# RL Num of allocation: 165
# TD3 Num of allocation: 165
# DDPG Num of allocation: 165
# epoch: 49
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 0
# ILP Allocated Num of Users: 246
# Greedy-Ngb Num of allocation: 243
# RL Num of allocation: 249
# TD3 Num of allocation: 249
# DDPG Num of allocation: 249
# epoch: 0
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 1
# ILP Allocated Num of Users: 212
# Greedy-Ngb Num of allocation: 204
# RL Num of allocation: 223
# TD3 Num of allocation: 223
# DDPG Num of allocation: 223
# epoch: 1
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 2
# ILP Allocated Num of Users: 246
# Greedy-Ngb Num of allocation: 241
# RL Num of allocation: 257
# TD3 Num of allocation: 257
# DDPG Num of allocation: 257
# epoch: 2
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 3
# ILP Allocated Num of Users: 254
# Greedy-Ngb Num of allocation: 253
# RL Num of allocation: 255
# TD3 Num of allocation: 255
# DDPG Num of allocation: 255
# epoch: 3
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 4
# ILP Allocated Num of Users: 251
# Greedy-Ngb Num of allocation: 249
# RL Num of allocation: 251
# TD3 Num of allocation: 251
# DDPG Num of allocation: 251
# epoch: 4
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 5
# ILP Allocated Num of Users: 244
# Greedy-Ngb Num of allocation: 239
# RL Num of allocation: 245
# TD3 Num of allocation: 245
# DDPG Num of allocation: 245
# epoch: 5
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 6
# ILP Allocated Num of Users: 252
# Greedy-Ngb Num of allocation: 250
# RL Num of allocation: 254
# TD3 Num of allocation: 254
# DDPG Num of allocation: 254
# epoch: 6
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 7
# ILP Allocated Num of Users: 249
# Greedy-Ngb Num of allocation: 247
# RL Num of allocation: 249
# TD3 Num of allocation: 249
# DDPG Num of allocation: 249
# epoch: 7
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 8
# ILP Allocated Num of Users: 256
# Greedy-Ngb Num of allocation: 253
# RL Num of allocation: 262
# TD3 Num of allocation: 262
# DDPG Num of allocation: 262
# epoch: 8
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 9
# ILP Allocated Num of Users: 240
# Greedy-Ngb Num of allocation: 235
# RL Num of allocation: 243
# TD3 Num of allocation: 243
# DDPG Num of allocation: 243
# epoch: 9
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 10
# ILP Allocated Num of Users: 232
# Greedy-Ngb Num of allocation: 228
# RL Num of allocation: 239
# TD3 Num of allocation: 239
# DDPG Num of allocation: 239
# epoch: 10
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 11
# ILP Allocated Num of Users: 244
# Greedy-Ngb Num of allocation: 235
# RL Num of allocation: 247
# TD3 Num of allocation: 247
# DDPG Num of allocation: 247
# epoch: 11
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 12
# ILP Allocated Num of Users: 247
# Greedy-Ngb Num of allocation: 243
# RL Num of allocation: 249
# TD3 Num of allocation: 249
# DDPG Num of allocation: 249
# epoch: 12
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 13
# ILP Allocated Num of Users: 265
# Greedy-Ngb Num of allocation: 257
# RL Num of allocation: 265
# TD3 Num of allocation: 265
# DDPG Num of allocation: 265
# epoch: 13
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 14
# ILP Allocated Num of Users: 233
# Greedy-Ngb Num of allocation: 228
# RL Num of allocation: 239
# TD3 Num of allocation: 239
# DDPG Num of allocation: 239
# epoch: 14
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 15
# ILP Allocated Num of Users: 237
# Greedy-Ngb Num of allocation: 234
# RL Num of allocation: 240
# TD3 Num of allocation: 240
# DDPG Num of allocation: 240
# epoch: 15
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 16
# ILP Allocated Num of Users: 234
# Greedy-Ngb Num of allocation: 229
# RL Num of allocation: 236
# TD3 Num of allocation: 236
# DDPG Num of allocation: 236
# epoch: 16
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 17
# ILP Allocated Num of Users: 230
# Greedy-Ngb Num of allocation: 226
# RL Num of allocation: 231
# TD3 Num of allocation: 231
# DDPG Num of allocation: 231
# epoch: 17
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 18
# ILP Allocated Num of Users: 236
# Greedy-Ngb Num of allocation: 231
# RL Num of allocation: 239
# TD3 Num of allocation: 239
# DDPG Num of allocation: 239
# epoch: 18
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 19
# ILP Allocated Num of Users: 228
# Greedy-Ngb Num of allocation: 223
# RL Num of allocation: 231
# TD3 Num of allocation: 231
# DDPG Num of allocation: 231
# epoch: 19
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 20
# ILP Allocated Num of Users: 265
# Greedy-Ngb Num of allocation: 257
# RL Num of allocation: 267
# TD3 Num of allocation: 267
# DDPG Num of allocation: 267
# epoch: 20
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 21
# ILP Allocated Num of Users: 238
# Greedy-Ngb Num of allocation: 235
# RL Num of allocation: 239
# TD3 Num of allocation: 239
# DDPG Num of allocation: 239
# epoch: 21
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 22
# ILP Allocated Num of Users: 253
# Greedy-Ngb Num of allocation: 245
# RL Num of allocation: 258
# TD3 Num of allocation: 258
# DDPG Num of allocation: 258
# epoch: 22
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 23
# ILP Allocated Num of Users: 233
# Greedy-Ngb Num of allocation: 228
# RL Num of allocation: 242
# TD3 Num of allocation: 242
# DDPG Num of allocation: 242
# epoch: 23
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 24
# ILP Allocated Num of Users: 233
# Greedy-Ngb Num of allocation: 227
# RL Num of allocation: 236
# TD3 Num of allocation: 236
# DDPG Num of allocation: 236
# epoch: 24
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 25
# ILP Allocated Num of Users: 245
# Greedy-Ngb Num of allocation: 242
# RL Num of allocation: 245
# TD3 Num of allocation: 245
# DDPG Num of allocation: 245
# epoch: 25
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 26
# ILP Allocated Num of Users: 247
# Greedy-Ngb Num of allocation: 246
# RL Num of allocation: 253
# TD3 Num of allocation: 253
# DDPG Num of allocation: 253
# epoch: 26
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 27
# ILP Allocated Num of Users: 230
# Greedy-Ngb Num of allocation: 226
# RL Num of allocation: 230
# TD3 Num of allocation: 230
# DDPG Num of allocation: 230
# epoch: 27
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 28
# ILP Allocated Num of Users: 241
# Greedy-Ngb Num of allocation: 237
# RL Num of allocation: 251
# TD3 Num of allocation: 251
# DDPG Num of allocation: 251
# epoch: 28
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 29
# ILP Allocated Num of Users: 233
# Greedy-Ngb Num of allocation: 225
# RL Num of allocation: 250
# TD3 Num of allocation: 250
# DDPG Num of allocation: 250
# epoch: 29
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 30
# ILP Allocated Num of Users: 242
# Greedy-Ngb Num of allocation: 238
# RL Num of allocation: 246
# TD3 Num of allocation: 246
# DDPG Num of allocation: 246
# epoch: 30
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 31
# ILP Allocated Num of Users: 239
# Greedy-Ngb Num of allocation: 234
# RL Num of allocation: 242
# TD3 Num of allocation: 242
# DDPG Num of allocation: 242
# epoch: 31
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 32
# ILP Allocated Num of Users: 238
# Greedy-Ngb Num of allocation: 237
# RL Num of allocation: 239
# TD3 Num of allocation: 239
# DDPG Num of allocation: 239
# epoch: 32
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 33
# ILP Allocated Num of Users: 215
# Greedy-Ngb Num of allocation: 214
# RL Num of allocation: 215
# TD3 Num of allocation: 215
# DDPG Num of allocation: 215
# epoch: 33
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 34
# ILP Allocated Num of Users: 248
# Greedy-Ngb Num of allocation: 245
# RL Num of allocation: 255
# TD3 Num of allocation: 255
# DDPG Num of allocation: 255
# epoch: 34
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 35
# ILP Allocated Num of Users: 249
# Greedy-Ngb Num of allocation: 246
# RL Num of allocation: 253
# TD3 Num of allocation: 253
# DDPG Num of allocation: 253
# epoch: 35
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 36
# ILP Allocated Num of Users: 219
# Greedy-Ngb Num of allocation: 215
# RL Num of allocation: 219
# TD3 Num of allocation: 219
# DDPG Num of allocation: 219
# epoch: 36
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 37
# ILP Allocated Num of Users: 244
# Greedy-Ngb Num of allocation: 237
# RL Num of allocation: 249
# TD3 Num of allocation: 249
# DDPG Num of allocation: 249
# epoch: 37
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 38
# ILP Allocated Num of Users: 250
# Greedy-Ngb Num of allocation: 246
# RL Num of allocation: 252
# TD3 Num of allocation: 252
# DDPG Num of allocation: 252
# epoch: 38
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 39
# ILP Allocated Num of Users: 239
# Greedy-Ngb Num of allocation: 234
# RL Num of allocation: 242
# TD3 Num of allocation: 242
# DDPG Num of allocation: 242
# epoch: 39
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 40
# ILP Allocated Num of Users: 258
# Greedy-Ngb Num of allocation: 252
# RL Num of allocation: 259
# TD3 Num of allocation: 259
# DDPG Num of allocation: 259
# epoch: 40
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 41
# ILP Allocated Num of Users: 227
# Greedy-Ngb Num of allocation: 225
# RL Num of allocation: 228
# TD3 Num of allocation: 228
# DDPG Num of allocation: 228
# epoch: 41
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 42
# ILP Allocated Num of Users: 246
# Greedy-Ngb Num of allocation: 241
# RL Num of allocation: 246
# TD3 Num of allocation: 246
# DDPG Num of allocation: 246
# epoch: 42
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 43
# ILP Allocated Num of Users: 238
# Greedy-Ngb Num of allocation: 235
# RL Num of allocation: 239
# TD3 Num of allocation: 239
# DDPG Num of allocation: 239
# epoch: 43
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 44
# ILP Allocated Num of Users: 252
# Greedy-Ngb Num of allocation: 247
# RL Num of allocation: 254
# TD3 Num of allocation: 254
# DDPG Num of allocation: 254
# epoch: 44
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 45
# ILP Allocated Num of Users: 234
# Greedy-Ngb Num of allocation: 228
# RL Num of allocation: 236
# TD3 Num of allocation: 236
# DDPG Num of allocation: 236
# epoch: 45
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 46
# ILP Allocated Num of Users: 241
# Greedy-Ngb Num of allocation: 238
# RL Num of allocation: 241
# TD3 Num of allocation: 241
# DDPG Num of allocation: 241
# epoch: 46
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 47
# ILP Allocated Num of Users: 253
# Greedy-Ngb Num of allocation: 250
# RL Num of allocation: 253
# TD3 Num of allocation: 253
# DDPG Num of allocation: 253
# epoch: 47
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 48
# ILP Allocated Num of Users: 236
# Greedy-Ngb Num of allocation: 234
# RL Num of allocation: 238
# TD3 Num of allocation: 238
# DDPG Num of allocation: 238
# epoch: 48
#
# ---------------------------------------
# User: 300 Server: 50 Epoch: 49
# ILP Allocated Num of Users: 239
# Greedy-Ngb Num of allocation: 235
# RL Num of allocation: 240
# TD3 Num of allocation: 240
# DDPG Num of allocation: 240
# epoch: 49
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 0
# ILP Allocated Num of Users: 333
# Greedy-Ngb Num of allocation: 320
# RL Num of allocation: 335
# TD3 Num of allocation: 335
# DDPG Num of allocation: 335
# epoch: 0
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 1
# ILP Allocated Num of Users: 303
# Greedy-Ngb Num of allocation: 297
# RL Num of allocation: 310
# TD3 Num of allocation: 310
# DDPG Num of allocation: 310
# epoch: 1
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 2
# ILP Allocated Num of Users: 312
# Greedy-Ngb Num of allocation: 301
# RL Num of allocation: 321
# TD3 Num of allocation: 321
# DDPG Num of allocation: 321
# epoch: 2
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 3
# ILP Allocated Num of Users: 326
# Greedy-Ngb Num of allocation: 315
# RL Num of allocation: 339
# TD3 Num of allocation: 339
# DDPG Num of allocation: 339
# epoch: 3
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 4
# ILP Allocated Num of Users: 317
# Greedy-Ngb Num of allocation: 295
# RL Num of allocation: 334
# TD3 Num of allocation: 334
# DDPG Num of allocation: 334
# epoch: 4
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 5
# ILP Allocated Num of Users: 311
# Greedy-Ngb Num of allocation: 298
# RL Num of allocation: 312
# TD3 Num of allocation: 312
# DDPG Num of allocation: 312
# epoch: 5
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 6
# ILP Allocated Num of Users: 329
# Greedy-Ngb Num of allocation: 315
# RL Num of allocation: 350
# TD3 Num of allocation: 350
# DDPG Num of allocation: 350
# epoch: 6
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 7
# ILP Allocated Num of Users: 320
# Greedy-Ngb Num of allocation: 313
# RL Num of allocation: 323
# TD3 Num of allocation: 323
# DDPG Num of allocation: 323
# epoch: 7
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 8
# ILP Allocated Num of Users: 320
# Greedy-Ngb Num of allocation: 310
# RL Num of allocation: 336
# TD3 Num of allocation: 336
# DDPG Num of allocation: 336
# epoch: 8
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 9
# ILP Allocated Num of Users: 317
# Greedy-Ngb Num of allocation: 301
# RL Num of allocation: 321
# TD3 Num of allocation: 321
# DDPG Num of allocation: 321
# epoch: 9
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 10
# ILP Allocated Num of Users: 310
# Greedy-Ngb Num of allocation: 300
# RL Num of allocation: 324
# TD3 Num of allocation: 324
# DDPG Num of allocation: 324
# epoch: 10
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 11
# ILP Allocated Num of Users: 334
# Greedy-Ngb Num of allocation: 322
# RL Num of allocation: 343
# TD3 Num of allocation: 343
# DDPG Num of allocation: 343
# epoch: 11
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 12
# ILP Allocated Num of Users: 340
# Greedy-Ngb Num of allocation: 328
# RL Num of allocation: 341
# TD3 Num of allocation: 341
# DDPG Num of allocation: 341
# epoch: 12
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 13
# ILP Allocated Num of Users: 334
# Greedy-Ngb Num of allocation: 325
# RL Num of allocation: 338
# TD3 Num of allocation: 338
# DDPG Num of allocation: 338
# epoch: 13
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 14
# ILP Allocated Num of Users: 330
# Greedy-Ngb Num of allocation: 315
# RL Num of allocation: 340
# TD3 Num of allocation: 340
# DDPG Num of allocation: 340
# epoch: 14
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 15
# ILP Allocated Num of Users: 324
# Greedy-Ngb Num of allocation: 307
# RL Num of allocation: 346
# TD3 Num of allocation: 346
# DDPG Num of allocation: 346
# epoch: 15
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 16
# ILP Allocated Num of Users: 283
# Greedy-Ngb Num of allocation: 277
# RL Num of allocation: 283
# TD3 Num of allocation: 283
# DDPG Num of allocation: 283
# epoch: 16
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 17
# ILP Allocated Num of Users: 314
# Greedy-Ngb Num of allocation: 307
# RL Num of allocation: 332
# TD3 Num of allocation: 332
# DDPG Num of allocation: 332
# epoch: 17
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 18
# ILP Allocated Num of Users: 346
# Greedy-Ngb Num of allocation: 330
# RL Num of allocation: 352
# TD3 Num of allocation: 352
# DDPG Num of allocation: 352
# epoch: 18
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 19
# ILP Allocated Num of Users: 342
# Greedy-Ngb Num of allocation: 329
# RL Num of allocation: 351
# TD3 Num of allocation: 351
# DDPG Num of allocation: 351
# epoch: 19
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 20
# ILP Allocated Num of Users: 340
# Greedy-Ngb Num of allocation: 320
# RL Num of allocation: 356
# TD3 Num of allocation: 356
# DDPG Num of allocation: 356
# epoch: 20
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 21
# ILP Allocated Num of Users: 329
# Greedy-Ngb Num of allocation: 311
# RL Num of allocation: 345
# TD3 Num of allocation: 345
# DDPG Num of allocation: 345
# epoch: 21
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 22
# ILP Allocated Num of Users: 330
# Greedy-Ngb Num of allocation: 319
# RL Num of allocation: 348
# TD3 Num of allocation: 348
# DDPG Num of allocation: 348
# epoch: 22
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 23
# ILP Allocated Num of Users: 300
# Greedy-Ngb Num of allocation: 295
# RL Num of allocation: 318
# TD3 Num of allocation: 318
# DDPG Num of allocation: 318
# epoch: 23
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 24
# ILP Allocated Num of Users: 318
# Greedy-Ngb Num of allocation: 303
# RL Num of allocation: 328
# TD3 Num of allocation: 328
# DDPG Num of allocation: 328
# epoch: 24
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 25
# ILP Allocated Num of Users: 333
# Greedy-Ngb Num of allocation: 320
# RL Num of allocation: 346
# TD3 Num of allocation: 346
# DDPG Num of allocation: 346
# epoch: 25
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 26
# ILP Allocated Num of Users: 326
# Greedy-Ngb Num of allocation: 315
# RL Num of allocation: 336
# TD3 Num of allocation: 336
# DDPG Num of allocation: 336
# epoch: 26
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 27
# ILP Allocated Num of Users: 321
# Greedy-Ngb Num of allocation: 313
# RL Num of allocation: 326
# TD3 Num of allocation: 326
# DDPG Num of allocation: 326
# epoch: 27
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 28
# ILP Allocated Num of Users: 308
# Greedy-Ngb Num of allocation: 294
# RL Num of allocation: 324
# TD3 Num of allocation: 324
# DDPG Num of allocation: 324
# epoch: 28
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 29
# ILP Allocated Num of Users: 290
# Greedy-Ngb Num of allocation: 278
# RL Num of allocation: 302
# TD3 Num of allocation: 302
# DDPG Num of allocation: 302
# epoch: 29
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 30
# ILP Allocated Num of Users: 327
# Greedy-Ngb Num of allocation: 316
# RL Num of allocation: 334
# TD3 Num of allocation: 334
# DDPG Num of allocation: 334
# epoch: 30
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 31
# ILP Allocated Num of Users: 284
# Greedy-Ngb Num of allocation: 267
# RL Num of allocation: 308
# TD3 Num of allocation: 308
# DDPG Num of allocation: 308
# epoch: 31
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 32
# ILP Allocated Num of Users: 303
# Greedy-Ngb Num of allocation: 287
# RL Num of allocation: 314
# TD3 Num of allocation: 314
# DDPG Num of allocation: 314
# epoch: 32
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 33
# ILP Allocated Num of Users: 329
# Greedy-Ngb Num of allocation: 314
# RL Num of allocation: 343
# TD3 Num of allocation: 343
# DDPG Num of allocation: 343
# epoch: 33
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 34
# ILP Allocated Num of Users: 330
# Greedy-Ngb Num of allocation: 320
# RL Num of allocation: 341
# TD3 Num of allocation: 341
# DDPG Num of allocation: 341
# epoch: 34
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 35
# ILP Allocated Num of Users: 333
# Greedy-Ngb Num of allocation: 319
# RL Num of allocation: 348
# TD3 Num of allocation: 348
# DDPG Num of allocation: 348
# epoch: 35
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 36
# ILP Allocated Num of Users: 338
# Greedy-Ngb Num of allocation: 325
# RL Num of allocation: 358
# TD3 Num of allocation: 358
# DDPG Num of allocation: 358
# epoch: 36
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 37
# ILP Allocated Num of Users: 307
# Greedy-Ngb Num of allocation: 290
# RL Num of allocation: 319
# TD3 Num of allocation: 319
# DDPG Num of allocation: 319
# epoch: 37
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 38
# ILP Allocated Num of Users: 313
# Greedy-Ngb Num of allocation: 305
# RL Num of allocation: 320
# TD3 Num of allocation: 320
# DDPG Num of allocation: 320
# epoch: 38
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 39
# ILP Allocated Num of Users: 330
# Greedy-Ngb Num of allocation: 315
# RL Num of allocation: 338
# TD3 Num of allocation: 338
# DDPG Num of allocation: 338
# epoch: 39
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 40
# ILP Allocated Num of Users: 303
# Greedy-Ngb Num of allocation: 298
# RL Num of allocation: 311
# TD3 Num of allocation: 311
# DDPG Num of allocation: 311
# epoch: 40
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 41
# ILP Allocated Num of Users: 329
# Greedy-Ngb Num of allocation: 311
# RL Num of allocation: 340
# TD3 Num of allocation: 340
# DDPG Num of allocation: 340
# epoch: 41
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 42
# ILP Allocated Num of Users: 327
# Greedy-Ngb Num of allocation: 309
# RL Num of allocation: 334
# TD3 Num of allocation: 334
# DDPG Num of allocation: 334
# epoch: 42
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 43
# ILP Allocated Num of Users: 286
# Greedy-Ngb Num of allocation: 279
# RL Num of allocation: 295
# TD3 Num of allocation: 295
# DDPG Num of allocation: 295
# epoch: 43
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 44
# ILP Allocated Num of Users: 316
# Greedy-Ngb Num of allocation: 298
# RL Num of allocation: 334
# TD3 Num of allocation: 334
# DDPG Num of allocation: 334
# epoch: 44
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 45
# ILP Allocated Num of Users: 337
# Greedy-Ngb Num of allocation: 327
# RL Num of allocation: 344
# TD3 Num of allocation: 344
# DDPG Num of allocation: 344
# epoch: 45
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 46
# ILP Allocated Num of Users: 312
# Greedy-Ngb Num of allocation: 302
# RL Num of allocation: 323
# TD3 Num of allocation: 323
# DDPG Num of allocation: 323
# epoch: 46
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 47
# ILP Allocated Num of Users: 318
# Greedy-Ngb Num of allocation: 307
# RL Num of allocation: 319
# TD3 Num of allocation: 319
# DDPG Num of allocation: 319
# epoch: 47
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 48
# ILP Allocated Num of Users: 313
# Greedy-Ngb Num of allocation: 299
# RL Num of allocation: 332
# TD3 Num of allocation: 332
# DDPG Num of allocation: 332
# epoch: 48
#
# ---------------------------------------
# User: 400 Server: 50 Epoch: 49
# ILP Allocated Num of Users: 321
# Greedy-Ngb Num of allocation: 306
# RL Num of allocation: 331
# TD3 Num of allocation: 331
# DDPG Num of allocation: 331
# epoch: 49
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 0
# ILP Allocated Num of Users: 382
# Greedy-Ngb Num of allocation: 359
# RL Num of allocation: 402
# TD3 Num of allocation: 402
# DDPG Num of allocation: 402
# epoch: 0
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 1
# ILP Allocated Num of Users: 384
# Greedy-Ngb Num of allocation: 366
# RL Num of allocation: 390
# TD3 Num of allocation: 390
# DDPG Num of allocation: 390
# epoch: 1
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 2
# ILP Allocated Num of Users: 368
# Greedy-Ngb Num of allocation: 346
# RL Num of allocation: 383
# TD3 Num of allocation: 383
# DDPG Num of allocation: 383
# epoch: 2
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 3
# ILP Allocated Num of Users: 408
# Greedy-Ngb Num of allocation: 383
# RL Num of allocation: 423
# TD3 Num of allocation: 423
# DDPG Num of allocation: 423
# epoch: 3
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 4
# ILP Allocated Num of Users: 376
# Greedy-Ngb Num of allocation: 349
# RL Num of allocation: 400
# TD3 Num of allocation: 400
# DDPG Num of allocation: 400
# epoch: 4
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 5
# ILP Allocated Num of Users: 392
# Greedy-Ngb Num of allocation: 369
# RL Num of allocation: 410
# TD3 Num of allocation: 410
# DDPG Num of allocation: 410
# epoch: 5
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 6
# ILP Allocated Num of Users: 403
# Greedy-Ngb Num of allocation: 374
# RL Num of allocation: 412
# TD3 Num of allocation: 412
# DDPG Num of allocation: 412
# epoch: 6
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 7
# ILP Allocated Num of Users: 360
# Greedy-Ngb Num of allocation: 332
# RL Num of allocation: 390
# TD3 Num of allocation: 390
# DDPG Num of allocation: 390
# epoch: 7
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 8
# ILP Allocated Num of Users: 393
# Greedy-Ngb Num of allocation: 373
# RL Num of allocation: 420
# TD3 Num of allocation: 420
# DDPG Num of allocation: 420
# epoch: 8
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 9
# ILP Allocated Num of Users: 363
# Greedy-Ngb Num of allocation: 342
# RL Num of allocation: 401
# TD3 Num of allocation: 401
# DDPG Num of allocation: 401
# epoch: 9
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 10
# ILP Allocated Num of Users: 403
# Greedy-Ngb Num of allocation: 385
# RL Num of allocation: 423
# TD3 Num of allocation: 423
# DDPG Num of allocation: 423
# epoch: 10
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 11
# ILP Allocated Num of Users: 371
# Greedy-Ngb Num of allocation: 343
# RL Num of allocation: 403
# TD3 Num of allocation: 403
# DDPG Num of allocation: 403
# epoch: 11
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 12
# ILP Allocated Num of Users: 385
# Greedy-Ngb Num of allocation: 361
# RL Num of allocation: 396
# TD3 Num of allocation: 396
# DDPG Num of allocation: 396
# epoch: 12
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 13
# ILP Allocated Num of Users: 382
# Greedy-Ngb Num of allocation: 359
# RL Num of allocation: 412
# TD3 Num of allocation: 412
# DDPG Num of allocation: 412
# epoch: 13
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 14
# ILP Allocated Num of Users: 398
# Greedy-Ngb Num of allocation: 380
# RL Num of allocation: 401
# TD3 Num of allocation: 401
# DDPG Num of allocation: 401
# epoch: 14
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 15
# ILP Allocated Num of Users: 348
# Greedy-Ngb Num of allocation: 327
# RL Num of allocation: 383
# TD3 Num of allocation: 383
# DDPG Num of allocation: 383
# epoch: 15
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 16
# ILP Allocated Num of Users: 362
# Greedy-Ngb Num of allocation: 340
# RL Num of allocation: 384
# TD3 Num of allocation: 384
# DDPG Num of allocation: 384
# epoch: 16
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 17
# ILP Allocated Num of Users: 357
# Greedy-Ngb Num of allocation: 336
# RL Num of allocation: 375
# TD3 Num of allocation: 375
# DDPG Num of allocation: 375
# epoch: 17
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 18
# ILP Allocated Num of Users: 404
# Greedy-Ngb Num of allocation: 375
# RL Num of allocation: 443
# TD3 Num of allocation: 443
# DDPG Num of allocation: 443
# epoch: 18
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 19
# ILP Allocated Num of Users: 396
# Greedy-Ngb Num of allocation: 372
# RL Num of allocation: 411
# TD3 Num of allocation: 411
# DDPG Num of allocation: 411
# epoch: 19
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 20
# ILP Allocated Num of Users: 391
# Greedy-Ngb Num of allocation: 369
# RL Num of allocation: 397
# TD3 Num of allocation: 397
# DDPG Num of allocation: 397
# epoch: 20
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 21
# ILP Allocated Num of Users: 383
# Greedy-Ngb Num of allocation: 364
# RL Num of allocation: 413
# TD3 Num of allocation: 413
# DDPG Num of allocation: 413
# epoch: 21
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 22
# ILP Allocated Num of Users: 367
# Greedy-Ngb Num of allocation: 346
# RL Num of allocation: 382
# TD3 Num of allocation: 382
# DDPG Num of allocation: 382
# epoch: 22
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 23
# ILP Allocated Num of Users: 380
# Greedy-Ngb Num of allocation: 353
# RL Num of allocation: 424
# TD3 Num of allocation: 424
# DDPG Num of allocation: 424
# epoch: 23
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 24
# ILP Allocated Num of Users: 362
# Greedy-Ngb Num of allocation: 345
# RL Num of allocation: 380
# TD3 Num of allocation: 380
# DDPG Num of allocation: 380
# epoch: 24
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 25
# ILP Allocated Num of Users: 366
# Greedy-Ngb Num of allocation: 354
# RL Num of allocation: 379
# TD3 Num of allocation: 379
# DDPG Num of allocation: 379
# epoch: 25
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 26
# ILP Allocated Num of Users: 394
# Greedy-Ngb Num of allocation: 363
# RL Num of allocation: 404
# TD3 Num of allocation: 404
# DDPG Num of allocation: 404
# epoch: 26
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 27
# ILP Allocated Num of Users: 383
# Greedy-Ngb Num of allocation: 361
# RL Num of allocation: 409
# TD3 Num of allocation: 409
# DDPG Num of allocation: 409
# epoch: 27
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 28
# ILP Allocated Num of Users: 378
# Greedy-Ngb Num of allocation: 348
# RL Num of allocation: 416
# TD3 Num of allocation: 416
# DDPG Num of allocation: 416
# epoch: 28
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 29
# ILP Allocated Num of Users: 389
# Greedy-Ngb Num of allocation: 370
# RL Num of allocation: 403
# TD3 Num of allocation: 403
# DDPG Num of allocation: 403
# epoch: 29
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 30
# ILP Allocated Num of Users: 386
# Greedy-Ngb Num of allocation: 369
# RL Num of allocation: 402
# TD3 Num of allocation: 402
# DDPG Num of allocation: 402
# epoch: 30
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 31
# ILP Allocated Num of Users: 360
# Greedy-Ngb Num of allocation: 334
# RL Num of allocation: 391
# TD3 Num of allocation: 391
# DDPG Num of allocation: 391
# epoch: 31
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 32
# ILP Allocated Num of Users: 397
# Greedy-Ngb Num of allocation: 365
# RL Num of allocation: 422
# TD3 Num of allocation: 422
# DDPG Num of allocation: 422
# epoch: 32
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 33
# ILP Allocated Num of Users: 412
# Greedy-Ngb Num of allocation: 390
# RL Num of allocation: 430
# TD3 Num of allocation: 430
# DDPG Num of allocation: 430
# epoch: 33
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 34
# ILP Allocated Num of Users: 373
# Greedy-Ngb Num of allocation: 356
# RL Num of allocation: 399
# TD3 Num of allocation: 399
# DDPG Num of allocation: 399
# epoch: 34
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 35
# ILP Allocated Num of Users: 371
# Greedy-Ngb Num of allocation: 348
# RL Num of allocation: 388
# TD3 Num of allocation: 388
# DDPG Num of allocation: 388
# epoch: 35
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 36
# ILP Allocated Num of Users: 399
# Greedy-Ngb Num of allocation: 363
# RL Num of allocation: 431
# TD3 Num of allocation: 431
# DDPG Num of allocation: 431
# epoch: 36
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 37
# ILP Allocated Num of Users: 362
# Greedy-Ngb Num of allocation: 335
# RL Num of allocation: 415
# TD3 Num of allocation: 415
# DDPG Num of allocation: 415
# epoch: 37
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 38
# ILP Allocated Num of Users: 409
# Greedy-Ngb Num of allocation: 388
# RL Num of allocation: 430
# TD3 Num of allocation: 430
# DDPG Num of allocation: 430
# epoch: 38
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 39
# ILP Allocated Num of Users: 381
# Greedy-Ngb Num of allocation: 363
# RL Num of allocation: 399
# TD3 Num of allocation: 399
# DDPG Num of allocation: 399
# epoch: 39
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 40
# ILP Allocated Num of Users: 400
# Greedy-Ngb Num of allocation: 378
# RL Num of allocation: 415
# TD3 Num of allocation: 415
# DDPG Num of allocation: 415
# epoch: 40
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 41
# ILP Allocated Num of Users: 355
# Greedy-Ngb Num of allocation: 344
# RL Num of allocation: 380
# TD3 Num of allocation: 380
# DDPG Num of allocation: 380
# epoch: 41
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 42
# ILP Allocated Num of Users: 379
# Greedy-Ngb Num of allocation: 354
# RL Num of allocation: 425
# TD3 Num of allocation: 425
# DDPG Num of allocation: 425
# epoch: 42
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 43
# ILP Allocated Num of Users: 411
# Greedy-Ngb Num of allocation: 374
# RL Num of allocation: 432
# TD3 Num of allocation: 432
# DDPG Num of allocation: 432
# epoch: 43
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 44
# ILP Allocated Num of Users: 381
# Greedy-Ngb Num of allocation: 354
# RL Num of allocation: 399
# TD3 Num of allocation: 399
# DDPG Num of allocation: 399
# epoch: 44
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 45
# ILP Allocated Num of Users: 367
# Greedy-Ngb Num of allocation: 350
# RL Num of allocation: 378
# TD3 Num of allocation: 378
# DDPG Num of allocation: 378
# epoch: 45
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 46
# ILP Allocated Num of Users: 372
# Greedy-Ngb Num of allocation: 348
# RL Num of allocation: 394
# TD3 Num of allocation: 394
# DDPG Num of allocation: 394
# epoch: 46
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 47
# ILP Allocated Num of Users: 357
# Greedy-Ngb Num of allocation: 327
# RL Num of allocation: 403
# TD3 Num of allocation: 403
# DDPG Num of allocation: 403
# epoch: 47
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 48
# ILP Allocated Num of Users: 400
# Greedy-Ngb Num of allocation: 367
# RL Num of allocation: 430
# TD3 Num of allocation: 430
# DDPG Num of allocation: 430
# epoch: 48
#
# ---------------------------------------
# User: 500 Server: 50 Epoch: 49
# ILP Allocated Num of Users: 395
# Greedy-Ngb Num of allocation: 371
# RL Num of allocation: 434
# TD3 Num of allocation: 434
# DDPG Num of allocation: 434
# epoch: 49

# %%
result_user
# Out:
#       user  server  ilp_user   ilp_time  greedy_user  greedy_time  dqn_user  \
# 0    100.0    50.0      79.0   0.277916         79.0     0.014201      79.0
# 1    100.0    50.0      81.0   0.114587         81.0     0.016471      81.0
# 2    100.0    50.0      76.0   0.112707         76.0     0.013562      76.0
# 3    100.0    50.0      84.0   0.126902         84.0     0.014713      84.0
# 4    100.0    50.0      79.0   0.129427         79.0     0.013858      79.0
# ..     ...     ...       ...        ...          ...          ...       ...
# 295  500.0    50.0     367.0   0.747484        350.0     0.074916     378.0
# 296  500.0    50.0     372.0   0.691128        348.0     0.072655     394.0
# 297  500.0    50.0     357.0   0.851538        327.0     0.069362     403.0
# 298  500.0    50.0     400.0  25.498679        367.0     0.075612     430.0
# 299  500.0    50.0     395.0  25.613156        371.0     0.073616     434.0
#
#      dqn_time  td3_user  td3_time  ddpg_user  ddpg_time
# 0    0.009815      79.0  0.011900       79.0   0.009985
# 1    0.010226      81.0  0.012035       81.0   0.012636
# 2    0.009957      76.0  0.010985       76.0   0.011405
# 3    0.009828      84.0  0.011464       84.0   0.011461
# 4    0.010313      79.0  0.011268       79.0   0.009982
# ..        ...       ...       ...        ...        ...
# 295  0.009209     378.0  0.014534      378.0   0.013794
# 296  0.009173     394.0  0.012999      394.0   0.013950
# 297  0.009372     403.0  0.013814      403.0   0.014436
# 298  0.009374     430.0  0.012724      430.0   0.011597
# 299  0.009536     434.0  0.012977      434.0   0.011257
#
# [300 rows x 12 columns]

# %% [markdown]
# end
